# %% [markdown]
# # hello world
#
# > Experiments with nbdev

# %%
#| default_exp nbdev_hello_world

# %%
#| hide
from nbdev.showdoc import *
from fastcore.test import *

# %%
#| export
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %%
test_eq(say_hello("Peebs"), "Hello Peebs!")

# %%
#| hide
import nbdev; nbdev.nbdev_export()
